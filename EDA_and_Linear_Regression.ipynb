# %% [markdown]
# # Predicting Song Popularity

# %% [markdown]
# This project aims to predict the popularity of a song by analyzing the affects of independent variables on song popularity.
#
# The dataset was initially sourced from Kaggle and contained data on 2,000 songs from Spotify.  Additional data was procured through API requests to the Spotify API to acquire artist follower count for each song as I suspected that this might have an influence on song popularity.
#
# Along with follower count, my overall hypothesis was that all my feautures would greatly predict popularity score.
#
# ### Data Cleaning
#
# - Two datasets were merged on artist name
# - All NaNs were assigned
# - Genres were consolidated for consistency and a simplier model
# - Dummy variables were created for each genre
# - A new feature was created from year released - "years since released"
# - A new feature was created for the total of words in each song title (I thought this may have an influence on popularity as well.)

# %% [markdown]
# ### Importing necessary libraries

# %%
import pickle
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import train_test_split
from sklearn.svm import SVR
import sklearn.metrics as metrics
from sklearn.metrics import mean_squared_error
from sklearn import linear_model
import statsmodels.api as sm
from statsmodels.formula.api import ols
import scipy.stats as stats
from sklearn.metrics import r2_score
pd.options.display.max_columns=100
pd.options.display.max_rows=100
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# ## EDA & Statistical Testing

# %%
#reading in cleaned, complete dataset
df=pd.read_csv('Data/song_data_final.csv',index_col=0)

# %%
#target variable is popularity score
target=df['Popularity']

# %% [markdown]
# #### What does the distribution of the target variable look like?

# %%
#distribution plot of target variable
#normal distribution, slightly left skewed 
sns.distplot(target)
plt.title('Distribution of Popularity Scores')

plt.show()

# %% [markdown]
# #### How do the relationships look between each feature and my target variable?
# The relationships mostly appear to be non-linear, I suspect that the effect of one feature may be dependent on another feature. Therefore, interactions and transformations of features should be strongly considered.

# %%
#scatterplots for all x and y relationships (genres not split out)
#mostly non-linear
#interactions should be considered

fig, axes = plt.subplots(nrows=5, ncols=3, figsize=(20,30), sharey=True)

for ax, column in zip(axes.flatten(), df.columns[2:17]):
    ax.scatter(df[column], df['Popularity'], label=column, alpha=1)
    ax.set_title(f'Popularity vs {column}')
    ax.set_xlabel(column)
    ax.set_ylabel('Popularity')

fig.tight_layout()

# %%
#histogram for all features except genre dummies
#most features are normally distributed
#transformations should be considered
df[['BPM', 'Energy', 'Danceability', 'Loudness_db',
       'Liveness', 'Valence', 'Duration', 'Acousticness', 'Speechiness',
        'Total Followers', 'yrs_since_release',
       'word_count_in_title']].hist(figsize=(18,15))
ax.ticklabel_format(style='plain')

plt.show()

# %%
#dropping categoricals that will not be used
#dummies created for genre
#year was utilized to calculate a new col, yrs_since_released
#title was utilized to caluclate a new col, word_count_in_title
df3=df.drop(columns=['Title','Artist','Top Genre','Year'])

# %% [markdown]
# #### What is the correlation between features? between each feature and popularity?
#
# Loudness and energy are highly correlated so my final model should just include one or an interaction between the two.
# No feature appears to be highly correlated with popularity on its own.

# %%
corr=df3.corr()
corr
# Out:
#                               BPM    Energy  Danceability  Loudness_db  \
# BPM                      1.000000  0.155437     -0.142008     0.091063
# Energy                   0.155437  1.000000      0.140519     0.735899
# Danceability            -0.142008  0.140519      1.000000     0.045922
# Loudness_db              0.091063  0.735899      0.045922     1.000000
# Liveness                 0.015976  0.174229     -0.102697     0.098452
# Valence                  0.059158  0.405303      0.514556     0.147376
# Duration                 0.008022  0.021607     -0.137026    -0.057941
# Acousticness            -0.120712 -0.665438     -0.137172    -0.452560
# Speechiness              0.085123  0.206048      0.125534     0.125403
# Popularity              -0.004635  0.104241      0.145635     0.166836
# Genre_metal                -0.016570   -0.038320        -0.026138
# Genre_opera                -0.014357    0.012105        -0.013090
# Genre_pop                   0.003534   -0.018253         0.073670
# Genre_punk                  0.011462    0.021250        -0.019061
# Genre_reggae                0.103248    0.037404         0.010690
# Genre_rock                 -0.049286    0.062635         0.049116
# Genre_singer-songwriter    -0.017941   -0.044823        -0.030936
# Genre_soul                  0.011881    0.090088         0.054062
#
#                          yrs_since_release  word_count_in_title  \
# BPM                              -0.011173            -0.027006
# Energy                           -0.147997             0.019736
# Danceability                     -0.078809            -0.025032
# Loudness_db                      -0.344729            -0.032545
# Liveness                         -0.019238             0.068774
# Valence                           0.165665             0.077637
# Duration                          0.051821             0.021516
# Acousticness                      0.134132             0.015333
# Speechiness                      -0.054414            -0.023045
# Popularity                        0.157486             0.016657
# Total Followers                  -0.096967             0.033921
# yrs_since_release                 1.000000             0.209290
# word_count_in_title               0.209290             1.000000
# Genre_adult standards             0.236242             0.028564
# Genre_alternative                -0.124333            -0.099843
# Genre_blues                       0.057991            -0.013959
# Genre_cabaret                    -0.075709            -0.018833
# Genre_carnaval limburg           -0.052050            -0.034976
# Genre_celtic                     -0.000061            -0.018137
# Genre_chanson                    -0.019945             0.004896
# Genre_classic                    -0.012569             0.012147
# Genre_country/americana          -0.040014            -0.037519
# Genre_dance                      -0.120783             0.000091
# Genre_disco                       0.009422             0.013134
# Genre_downtempo                  -0.029254            -0.002525
# Genre_folk                       -0.029905            -0.032176
# Genre_funk                        0.038167            -0.022235
# Genre_gabba                      -0.034434             0.053518
# Genre_hip hop/rap                -0.109602            -0.056685
# Genre_indie                      -0.129074            -0.054638
# Genre_jazz                       -0.003531            -0.007416
# Genre_latin                      -0.031348            -0.016300
# Genre_mellow gold                -0.008910             0.112501
# Genre_metal                      -0.046638            -0.039050
# Genre_opera                      -0.003969            -0.008697
# Genre_pop                        -0.236173            -0.067537
# Genre_punk                        0.019843             0.016865
# Genre_reggae                      0.053801             0.032398
# Genre_rock                        0.351173             0.164815
# Genre_singer-songwriter          -0.046334            -0.007036
# Genre_soul                       -0.033221             0.002164
#
#                          Genre_adult standards  Genre_alternative  \
# BPM                                  -0.033170           0.015995
# Energy                               -0.189693           0.176292
# Danceability                         -0.085609          -0.108869
# Loudness_db                          -0.180936           0.174842
# Liveness                              0.016281           0.008087
# Valence                               0.036743          -0.072781
# Duration                             -0.114483           0.023187
# Acousticness                          0.189473          -0.186776
# Speechiness                          -0.056074          -0.004276
# Popularity                            0.045496           0.108686
# Total Followers                      -0.085727          -0.013705
# yrs_since_release                     0.236242          -0.124333
# word_count_in_title                   0.028564          -0.099843
# Genre_adult standards                 1.000000          -0.077230
# Genre_alternative                    -0.077230           1.000000
# Genre_blues                          -0.015328          -0.020286
# Genre_cabaret                        -0.040293          -0.053325
# Genre_carnaval limburg               -0.017146          -0.022692
# Genre_celtic                         -0.012109          -0.016025
# Genre_chanson                        -0.013268          -0.017559
# Genre_classic                        -0.010828          -0.014330
# Genre_country/americana              -0.029848          -0.039503
# Genre_dance                          -0.037112          -0.049116
# Genre_disco                          -0.023050          -0.030506
# Genre_downtempo                      -0.010828          -0.014330
# Genre_folk                           -0.031329          -0.041462
# Genre_funk                           -0.019564          -0.025892
# Genre_gabba                          -0.007652          -0.010128
# Genre_hip hop/rap                    -0.032281          -0.042722
# Genre_indie                          -0.048074          -0.063623
# Genre_jazz                           -0.010828          -0.014330
# Genre_latin                          -0.009375          -0.012407
# Genre_mellow gold                    -0.017987          -0.023805
# Genre_metal                          -0.013268          -0.017559
# Genre_opera                          -0.007652          -0.010128
# Genre_pop                            -0.120595          -0.159601
# Genre_punk                           -0.012109          -0.016025
# Genre_reggae                         -0.018792          -0.024870
# Genre_rock                           -0.202850          -0.268461
# Genre_singer-songwriter              -0.015328          -0.020286
# Genre_soul                           -0.038732          -0.051259
#
#                          Genre_blues  Genre_cabaret  Genre_carnaval limburg  \
# BPM                        -0.016387      -0.011788                0.084201
# Energy                     -0.000477      -0.077253               -0.016235
# Danceability                0.048140      -0.001227               -0.083305
# Loudness_db                -0.032391      -0.074779                0.004124
# Liveness                    0.011824       0.015054                0.027553
# Valence                     0.043981      -0.026321               -0.024002
# Duration                   -0.027719      -0.040074               -0.011700
# Acousticness                0.031138       0.102422                0.025476
# Speechiness                 0.030734       0.020588                0.009777
# Popularity                 -0.001723      -0.148005               -0.113802
# Total Followers            -0.033160      -0.094471               -0.041861
# yrs_since_release           0.057991      -0.075709               -0.052050
# word_count_in_title        -0.013959      -0.018833               -0.034976
# Genre_adult standards      -0.015328      -0.040293               -0.017146
# Genre_alternative          -0.020286      -0.053325               -0.022692
# Genre_blues                 1.000000      -0.010584               -0.004504
# Genre_cabaret              -0.010584       1.000000               -0.011839
# Genre_carnaval limburg     -0.004504      -0.011839                1.000000
# Genre_celtic               -0.003181      -0.008361               -0.003558
# Genre_chanson              -0.003485      -0.009161               -0.003898
# Genre_classic              -0.002844      -0.007476               -0.003181
# Genre_country/americana    -0.007840      -0.020609               -0.008770
# Genre_dance                -0.009748      -0.025625               -0.010904
# Genre_disco                -0.006055      -0.015915               -0.006773
# Genre_downtempo            -0.002844      -0.007476               -0.003181
# Genre_folk                 -0.008229      -0.021632               -0.009205
# Genre_funk                 -0.005139      -0.013508               -0.005748
# Genre_gabba                -0.002010      -0.005284               -0.002248
# Genre_hip hop/rap          -0.008479      -0.022289               -0.009485
# Genre_indie                -0.012627      -0.033194               -0.014125
# Genre_jazz                 -0.002844      -0.007476               -0.003181
# Genre_latin                -0.002462      -0.006473               -0.002754
# Genre_mellow gold          -0.004725      -0.012420               -0.005285
# Genre_metal                -0.003485      -0.009161               -0.003898
# Genre_opera                -0.002010      -0.005284               -0.002248
# Genre_pop                  -0.031676      -0.083267               -0.035433
# Genre_punk                 -0.003181      -0.008361               -0.003558
# Genre_reggae               -0.004936      -0.012975               -0.005521
# Genre_rock                 -0.053282      -0.140061               -0.059601
# Genre_singer-songwriter    -0.004026      -0.010584               -0.004504
# Genre_soul                 -0.010174      -0.026743               -0.011380
#
#                          Genre_celtic  Genre_chanson  Genre_classic  \
# BPM                          0.014588      -0.024959      -0.025165
# Energy                      -0.058535      -0.020250      -0.037772
# Genre_funk                -0.068007                -0.005139   -0.012985
# Genre_gabba               -0.026601                -0.002010   -0.005079
# Genre_hip hop/rap         -0.112212                -0.008479   -0.021426
# Genre_indie               -0.167110                -0.012627   -0.031908
# Genre_jazz                -0.037638                -0.002844   -0.007187
# Genre_latin               -0.032587                -0.002462   -0.006222
# Genre_mellow gold         -0.062526                -0.004725   -0.011939
# Genre_metal               -0.046120                -0.003485   -0.008806
# Genre_opera               -0.026601                -0.002010   -0.005079
# Genre_pop                 -0.419202                -0.031676   -0.080041
# Genre_punk                -0.042091                -0.003181   -0.008037
# Genre_reggae              -0.065323                -0.004936   -0.012473
# Genre_rock                 1.000000                -0.053282   -0.134635
# Genre_singer-songwriter   -0.053282                 1.000000   -0.010174
# Genre_soul                -0.134635                -0.010174    1.000000

# %%
#perhaps multicollinearity between loudness and energy
#checking correlation for all over .5
#no features appear to be highly correlated with popularity
corr[abs(corr>.50)]
# Out:
#                          BPM    Energy  Danceability  Loudness_db  Liveness  \
# BPM                      1.0       NaN           NaN          NaN       NaN
# Energy                   NaN  1.000000           NaN     0.735899       NaN
# Danceability             NaN       NaN      1.000000          NaN       NaN
# Loudness_db              NaN  0.735899           NaN     1.000000       NaN
# Liveness                 NaN       NaN           NaN          NaN       1.0
# Valence                  NaN       NaN      0.514556          NaN       NaN
# Duration                 NaN       NaN           NaN          NaN       NaN
# Acousticness             NaN       NaN           NaN          NaN       NaN
# Speechiness              NaN       NaN           NaN          NaN       NaN
# Popularity               NaN       NaN           NaN          NaN       NaN
# Total Followers          NaN       NaN           NaN          NaN       NaN
# yrs_since_release        NaN       NaN           NaN          NaN       NaN
# word_count_in_title      NaN       NaN           NaN          NaN       NaN
# Genre_adult standards    NaN       NaN           NaN          NaN       NaN
# Genre_alternative        NaN       NaN           NaN          NaN       NaN
# Genre_blues              NaN       NaN           NaN          NaN       NaN
# Genre_cabaret            NaN       NaN           NaN          NaN       NaN
# Genre_carnaval limburg   NaN       NaN           NaN          NaN       NaN
# Genre_celtic             NaN       NaN           NaN          NaN       NaN
# Genre_chanson            NaN       NaN           NaN          NaN       NaN
# Genre_classic            NaN       NaN           NaN          NaN       NaN
# Genre_country/americana  NaN       NaN           NaN          NaN       NaN
# Genre_dance              NaN       NaN           NaN          NaN       NaN
# Genre_disco              NaN       NaN           NaN          NaN       NaN
# Genre_downtempo          NaN       NaN           NaN          NaN       NaN
# Genre_folk               NaN       NaN           NaN          NaN       NaN
# Genre_funk               NaN       NaN           NaN          NaN       NaN
# Genre_gabba              NaN       NaN           NaN          NaN       NaN
# Genre_hip hop/rap        NaN       NaN           NaN          NaN       NaN
# Genre_indie              NaN       NaN           NaN          NaN       NaN
# Genre_jazz               NaN       NaN           NaN          NaN       NaN
# Genre_latin              NaN       NaN           NaN          NaN       NaN
# Genre_mellow gold        NaN       NaN           NaN          NaN       NaN
# Genre_metal              NaN       NaN           NaN          NaN       NaN
# Genre_opera              NaN       NaN           NaN          NaN       NaN
# Genre_pop                NaN       NaN           NaN          NaN       NaN
# Genre_punk               NaN       NaN           NaN          NaN       NaN
# Genre_reggae             NaN       NaN           NaN          NaN       NaN
# Genre_rock               NaN       NaN           NaN          NaN       NaN
# Genre_singer-songwriter  NaN       NaN           NaN          NaN       NaN
# Genre_soul               NaN       NaN           NaN          NaN       NaN
#
#                           Valence  Duration  Acousticness  Speechiness  \
# BPM                           NaN       NaN           NaN          NaN
# Energy                        NaN       NaN           NaN          NaN
# Danceability             0.514556       NaN           NaN          NaN
# Loudness_db                   NaN       NaN           NaN          NaN
# Liveness                      NaN       NaN           NaN          NaN
# Valence                  1.000000       NaN           NaN          NaN
# Duration                      NaN       1.0           NaN          NaN
# Acousticness                  NaN       NaN           1.0          NaN
# Speechiness                   NaN       NaN           NaN          1.0
# Popularity                    NaN       NaN           NaN          NaN
# Total Followers               NaN       NaN           NaN          NaN
# yrs_since_release             NaN       NaN           NaN          NaN
# word_count_in_title           NaN       NaN           NaN          NaN
# Genre_adult standards         NaN       NaN           NaN          NaN
# Genre_alternative             NaN       NaN           NaN          NaN
# Genre_blues                   NaN       NaN           NaN          NaN
# Genre_cabaret                 NaN       NaN           NaN          NaN
# Genre_carnaval limburg        NaN       NaN           NaN          NaN
# Genre_celtic                  NaN       NaN           NaN          NaN
# Genre_chanson                 NaN       NaN           NaN          NaN
# Genre_classic                 NaN       NaN           NaN          NaN
# Genre_country/americana       NaN       NaN           NaN          NaN
# Genre_dance                   NaN       NaN           NaN          NaN
# Genre_disco                   NaN       NaN           NaN          NaN
# Genre_downtempo               NaN       NaN           NaN          NaN
# Genre_folk                    NaN       NaN           NaN          NaN
# Genre_funk                    NaN       NaN           NaN          NaN
# Genre_gabba                   NaN       NaN           NaN          NaN
# Genre_hip hop/rap             NaN       NaN           NaN          NaN
# Genre_indie                   NaN       NaN           NaN          NaN
# Genre_jazz                    NaN       NaN           NaN          NaN
# Genre_latin                   NaN       NaN           NaN          NaN
# Genre_mellow gold             NaN       NaN           NaN          NaN
# Genre_metal                   NaN       NaN           NaN          NaN
# Genre_opera                   NaN       NaN           NaN          NaN
# Genre_pop                     NaN       NaN           NaN          NaN
# Genre_punk                    NaN       NaN           NaN          NaN
# Genre_reggae                  NaN       NaN           NaN          NaN
# Genre_rock                    NaN       NaN           NaN          NaN
# Genre_singer-songwriter       NaN       NaN           NaN          NaN
# Genre_soul                    NaN       NaN           NaN          NaN
#
#                          Popularity  Total Followers  yrs_since_release  \
# BPM                             NaN              NaN                NaN
# Energy                          NaN              NaN                NaN
# Danceability                    NaN              NaN                NaN
# Loudness_db                     NaN              NaN                NaN
# Liveness                        NaN              NaN                NaN
# Valence                         NaN              NaN                NaN
# Duration                        NaN              NaN                NaN
# Acousticness                    NaN              NaN                NaN
# Speechiness                     NaN              NaN                NaN
# Popularity                      1.0              NaN                NaN
# Total Followers                 NaN              1.0                NaN
# yrs_since_release               NaN              NaN                1.0
# word_count_in_title             NaN              NaN                NaN
# Genre_adult standards           NaN              NaN                NaN
# Genre_alternative               NaN              NaN                NaN
# Genre_blues                     NaN              NaN                NaN
# Genre_cabaret                   NaN              NaN                NaN
# Genre_carnaval limburg          NaN              NaN                NaN
# Genre_celtic                    NaN              NaN                NaN
# Genre_chanson                   NaN              NaN                NaN
# Genre_classic                   NaN              NaN                NaN
# Genre_country/americana         NaN              NaN                NaN
# Genre_dance                     NaN              NaN                NaN
# Genre_disco                     NaN              NaN                NaN
# Genre_downtempo                 NaN              NaN                NaN
# Genre_folk                      NaN              NaN                NaN
# Genre_funk                      NaN              NaN                NaN
# Genre_gabba                     NaN              NaN                NaN
# Genre_hip hop/rap               NaN              NaN                NaN
# Genre_indie                     NaN              NaN                NaN
# Genre_jazz                      NaN              NaN                NaN
# Genre_latin                     NaN              NaN                NaN
# Genre_mellow gold               NaN              NaN                NaN
# Genre_metal                     NaN              NaN                NaN
# Genre_opera                     NaN              NaN                NaN
# Genre_pop                       NaN              NaN                NaN
# Genre_punk                      NaN              NaN                NaN
# Genre_reggae                    NaN              NaN                NaN
# Genre_rock                      NaN              NaN                NaN
# Genre_singer-songwriter         NaN              NaN                NaN
# Genre_soul                      NaN              NaN                NaN
#
#                          word_count_in_title  Genre_adult standards  \
# BPM                                      NaN                    NaN
# Energy                                   NaN                    NaN
# Danceability                             NaN                    NaN
# Loudness_db                              NaN                    NaN
# Liveness                                 NaN                    NaN
# Valence                                  NaN                    NaN
# Duration                                 NaN                    NaN
# Acousticness                             NaN                    NaN
# Speechiness                              NaN                    NaN
# Popularity                               NaN                    NaN
# Total Followers                          NaN                    NaN
# yrs_since_release                        NaN                    NaN
# word_count_in_title                      1.0                    NaN
# Genre_adult standards                    NaN                    1.0
# Genre_alternative                        NaN                    NaN
# Genre_blues                              NaN                    NaN
# Genre_cabaret                            NaN                    NaN
# Genre_carnaval limburg                   NaN                    NaN
# Genre_celtic                             NaN                    NaN
# Genre_chanson                            NaN                    NaN
# Genre_classic                            NaN                    NaN
# Genre_country/americana                  NaN                    NaN
# Genre_dance                              NaN                    NaN
# Genre_disco                              NaN                    NaN
# Genre_downtempo                          NaN                    NaN
# Genre_folk                               NaN                    NaN
# Genre_funk                               NaN                    NaN
# Genre_gabba                              NaN                    NaN
# Genre_hip hop/rap                        NaN                    NaN
# Genre_indie                              NaN                    NaN
# Genre_jazz                               NaN                    NaN
# Genre_latin                              NaN                    NaN
# Genre_mellow gold                        NaN                    NaN
# Genre_metal                              NaN                    NaN
# Genre_opera                              NaN                    NaN
# Genre_pop                                NaN                    NaN
# Genre_punk                               NaN                    NaN
# Genre_reggae                             NaN                    NaN
# Genre_rock                               NaN                    NaN
# Genre_singer-songwriter                  NaN                    NaN
# Genre_soul                               NaN                    NaN
#
#                          Genre_alternative  Genre_blues  Genre_cabaret  \
# BPM                                    NaN          NaN            NaN
# Energy                                 NaN          NaN            NaN
# Danceability                           NaN          NaN            NaN
# Loudness_db                            NaN          NaN            NaN
# Liveness                               NaN          NaN            NaN
# Valence                                NaN          NaN            NaN
# Duration                               NaN          NaN            NaN
# Acousticness                           NaN          NaN            NaN
# Speechiness                            NaN          NaN            NaN
# Popularity                             NaN          NaN            NaN
# Total Followers                        NaN          NaN            NaN
# yrs_since_release                      NaN          NaN            NaN
# word_count_in_title                    NaN          NaN            NaN
# Genre_adult standards                  NaN          NaN            NaN
# Genre_alternative                      1.0          NaN            NaN
# Genre_blues                            NaN          1.0            NaN
# Genre_cabaret                          NaN          NaN            1.0
# Genre_carnaval limburg                 NaN          NaN            NaN
# Genre_celtic                           NaN          NaN            NaN
# Genre_chanson                          NaN          NaN            NaN
# Genre_classic                          NaN          NaN            NaN
# Genre_country/americana                NaN          NaN            NaN
# Genre_dance                            NaN          NaN            NaN
# Genre_disco                            NaN          NaN            NaN
# Genre_downtempo                        NaN          NaN            NaN
# Genre_folk                             NaN          NaN            NaN
# Genre_funk                             NaN          NaN            NaN
# Genre_gabba                            NaN          NaN            NaN
# Genre_hip hop/rap                      NaN          NaN            NaN
# Genre_indie                            NaN          NaN            NaN
# Genre_jazz                             NaN          NaN            NaN
# Genre_latin                            NaN          NaN            NaN
# Genre_mellow gold                      NaN          NaN            NaN
# Genre_metal                            NaN          NaN            NaN
# Genre_opera                            NaN          NaN            NaN
# Genre_pop                              NaN          NaN            NaN
# Genre_punk                             NaN          NaN            NaN
# Genre_reggae                           NaN          NaN            NaN
# Genre_rock                             NaN          NaN            NaN
# Genre_singer-songwriter                NaN          NaN            NaN
# Genre_soul                             NaN          NaN            NaN
#
#                          Genre_carnaval limburg  Genre_celtic  Genre_chanson  \
# BPM                                         NaN           NaN            NaN
# Energy                                      NaN           NaN            NaN
# Danceability                                NaN           NaN            NaN
# Loudness_db                                 NaN           NaN            NaN
# Liveness                                    NaN           NaN            NaN
# Valence                                     NaN           NaN            NaN
# Duration                                    NaN           NaN            NaN
# Acousticness                                NaN           NaN            NaN
# Speechiness                                 NaN           NaN            NaN
# Popularity                                  NaN           NaN            NaN
# Total Followers                             NaN           NaN            NaN
# yrs_since_release                           NaN           NaN            NaN
# word_count_in_title                         NaN           NaN            NaN
# Genre_adult standards                       NaN           NaN            NaN
# Genre_alternative                           NaN           NaN            NaN
# Genre_blues                                 NaN           NaN            NaN
# Genre_cabaret                               NaN           NaN            NaN
# Genre_carnaval limburg                      1.0           NaN            NaN
# Genre_celtic                                NaN           1.0            NaN
# Genre_chanson                               NaN           NaN            1.0
# Genre_classic                               NaN           NaN            NaN
# Genre_country/americana                     NaN           NaN            NaN
# Genre_dance                                 NaN           NaN            NaN
# Genre_disco                                 NaN           NaN            NaN
# Genre_downtempo                             NaN           NaN            NaN
# Genre_folk                                  NaN           NaN            NaN
# Genre_funk                                  NaN           NaN            NaN
# Genre_gabba                                 NaN           NaN            NaN
# Genre_hip hop/rap                           NaN           NaN            NaN
# Genre_indie                                 NaN           NaN            NaN
# Genre_jazz                                  NaN           NaN            NaN
# Genre_latin                                 NaN           NaN            NaN
# Genre_mellow gold                           NaN           NaN            NaN
# Genre_metal                                 NaN           NaN            NaN
# Genre_opera                                 NaN           NaN            NaN
# Genre_pop                                   NaN           NaN            NaN
# Genre_punk                                  NaN           NaN            NaN
# Genre_reggae                                NaN           NaN            NaN
# Genre_rock                                  NaN           NaN            NaN
# Genre_singer-songwriter                     NaN           NaN            NaN
# Genre_soul                                  NaN           NaN            NaN
#
#                          Genre_classic  Genre_country/americana  Genre_dance  \
# BPM                                NaN                      NaN          NaN
# Energy                             NaN                      NaN          NaN
# Danceability                       NaN                      NaN          NaN
# Loudness_db                        NaN                      NaN          NaN
# Liveness                           NaN                      NaN          NaN
# Valence                            NaN                      NaN          NaN
# Duration                           NaN                      NaN          NaN
# Acousticness                       NaN                      NaN          NaN
# Speechiness                        NaN                      NaN          NaN
# Popularity                         NaN                      NaN          NaN
# Total Followers                    NaN                      NaN          NaN
# yrs_since_release                  NaN                      NaN          NaN
# word_count_in_title                NaN                      NaN          NaN
# Genre_adult standards              NaN                      NaN          NaN
# Genre_alternative                  NaN                      NaN          NaN
# Genre_blues                        NaN                      NaN          NaN
# Genre_cabaret                      NaN                      NaN          NaN
# Genre_carnaval limburg             NaN                      NaN          NaN
# Genre_celtic                       NaN                      NaN          NaN
# Genre_chanson                      NaN                      NaN          NaN
# Genre_classic                      1.0                      NaN          NaN
# Genre_country/americana            NaN                      1.0          NaN
# Genre_dance                        NaN                      NaN          1.0
# Genre_disco                        NaN                      NaN          NaN
# Genre_downtempo                    NaN                      NaN          NaN
# Genre_folk                         NaN                      NaN          NaN
# Genre_funk                         NaN                      NaN          NaN
# Genre_gabba                        NaN                      NaN          NaN
# Genre_hip hop/rap                  NaN                      NaN          NaN
# Genre_indie                        NaN                      NaN          NaN
# Genre_jazz                         NaN                      NaN          NaN
# Genre_latin                        NaN                      NaN          NaN
# Genre_mellow gold                  NaN                      NaN          NaN
# Genre_metal                        NaN                      NaN          NaN
# Genre_opera                        NaN                      NaN          NaN
# Genre_pop                          NaN                      NaN          NaN
# Genre_punk                         NaN                      NaN          NaN
# Genre_reggae                       NaN                      NaN          NaN
# Genre_rock                         NaN                      NaN          NaN
# Genre_singer-songwriter            NaN                      NaN          NaN
# Genre_soul                         NaN                      NaN          NaN
#
#                          Genre_disco  Genre_downtempo  Genre_folk  Genre_funk  \
# BPM                              NaN              NaN         NaN         NaN
# Energy                           NaN              NaN         NaN         NaN
# Danceability                     NaN              NaN         NaN         NaN
# Loudness_db                      NaN              NaN         NaN         NaN
# Liveness                         NaN              NaN         NaN         NaN
# Valence                          NaN              NaN         NaN         NaN
# Duration                         NaN              NaN         NaN         NaN
# Acousticness                     NaN              NaN         NaN         NaN
# Speechiness                      NaN              NaN         NaN         NaN
# Popularity                       NaN              NaN         NaN         NaN
# Total Followers                  NaN              NaN         NaN         NaN
# yrs_since_release                NaN              NaN         NaN         NaN
# word_count_in_title              NaN              NaN         NaN         NaN
# Genre_adult standards            NaN              NaN         NaN         NaN
# Genre_alternative                NaN              NaN         NaN         NaN
# Genre_blues                      NaN              NaN         NaN         NaN
# Genre_cabaret                    NaN              NaN         NaN         NaN
# Genre_carnaval limburg           NaN              NaN         NaN         NaN
# Genre_celtic                     NaN              NaN         NaN         NaN
# Genre_chanson                    NaN              NaN         NaN         NaN
# Genre_classic                    NaN              NaN         NaN         NaN
# Genre_country/americana          NaN              NaN         NaN         NaN
# Genre_dance                      NaN              NaN         NaN         NaN
# Genre_disco                      1.0              NaN         NaN         NaN
# Genre_downtempo                  NaN              1.0         NaN         NaN
# Genre_folk                       NaN              NaN         1.0         NaN
# Genre_funk                       NaN              NaN         NaN         1.0
# Genre_gabba                      NaN              NaN         NaN         NaN
# Genre_hip hop/rap                NaN              NaN         NaN         NaN
# Genre_indie                      NaN              NaN         NaN         NaN
# Genre_jazz                       NaN              NaN         NaN         NaN
# Genre_latin                      NaN              NaN         NaN         NaN
# Genre_mellow gold                NaN              NaN         NaN         NaN
# Genre_metal                      NaN              NaN         NaN         NaN
# Genre_opera                      NaN              NaN         NaN         NaN
# Genre_pop                        NaN              NaN         NaN         NaN
# Genre_punk                       NaN              NaN         NaN         NaN
# Genre_reggae                     NaN              NaN         NaN         NaN
# Genre_rock                       NaN              NaN         NaN         NaN
# Genre_singer-songwriter          NaN              NaN         NaN         NaN
# Genre_soul                       NaN              NaN         NaN         NaN
#
#                          Genre_gabba  Genre_hip hop/rap  Genre_indie  \
# BPM                              NaN                NaN          NaN
# Energy                           NaN                NaN          NaN
# Danceability                     NaN                NaN          NaN
# Loudness_db                      NaN                NaN          NaN
# Liveness                         NaN                NaN          NaN
# Valence                          NaN                NaN          NaN
# Duration                         NaN                NaN          NaN
# Acousticness                     NaN                NaN          NaN
# Speechiness                      NaN                NaN          NaN
# Popularity                       NaN                NaN          NaN
# Total Followers                  NaN                NaN          NaN
# yrs_since_release                NaN                NaN          NaN
# word_count_in_title              NaN                NaN          NaN
# Genre_adult standards            NaN                NaN          NaN
# Genre_alternative                NaN                NaN          NaN
# Genre_blues                      NaN                NaN          NaN
# Genre_cabaret                    NaN                NaN          NaN
# Genre_carnaval limburg           NaN                NaN          NaN
# Genre_celtic                     NaN                NaN          NaN
# Genre_chanson                    NaN                NaN          NaN
# Genre_classic                    NaN                NaN          NaN
# Genre_country/americana          NaN                NaN          NaN
# Genre_dance                      NaN                NaN          NaN
# Genre_disco                      NaN                NaN          NaN
# Genre_downtempo                  NaN                NaN          NaN
# Genre_folk                       NaN                NaN          NaN
# Genre_funk                       NaN                NaN          NaN
# Genre_gabba                      1.0                NaN          NaN
# Genre_hip hop/rap                NaN                1.0          NaN
# Genre_indie                      NaN                NaN          1.0
# Genre_jazz                       NaN                NaN          NaN
# Genre_latin                      NaN                NaN          NaN
# Genre_mellow gold                NaN                NaN          NaN
# Genre_metal                      NaN                NaN          NaN
# Genre_opera                      NaN                NaN          NaN
# Genre_pop                        NaN                NaN          NaN
# Genre_punk                       NaN                NaN          NaN
# Genre_reggae                     NaN                NaN          NaN
# Genre_rock                       NaN                NaN          NaN
# Genre_singer-songwriter          NaN                NaN          NaN
# Genre_soul                       NaN                NaN          NaN
#
#                          Genre_jazz  Genre_latin  Genre_mellow gold  \
# BPM                             NaN          NaN                NaN
# Energy                          NaN          NaN                NaN
# Danceability                    NaN          NaN                NaN
# Loudness_db                     NaN          NaN                NaN
# Liveness                        NaN          NaN                NaN
# Valence                         NaN          NaN                NaN
# Duration                        NaN          NaN                NaN
# Acousticness                    NaN          NaN                NaN
# Speechiness                     NaN          NaN                NaN
# Popularity                      NaN          NaN                NaN
# Total Followers                 NaN          NaN                NaN
# yrs_since_release               NaN          NaN                NaN
# word_count_in_title             NaN          NaN                NaN
# Genre_adult standards           NaN          NaN                NaN
# Genre_alternative               NaN          NaN                NaN
# Genre_blues                     NaN          NaN                NaN
# Genre_cabaret                   NaN          NaN                NaN
# Genre_carnaval limburg          NaN          NaN                NaN
# Genre_celtic                    NaN          NaN                NaN
# Genre_chanson                   NaN          NaN                NaN
# Genre_classic                   NaN          NaN                NaN
# Genre_country/americana         NaN          NaN                NaN
# Genre_dance                     NaN          NaN                NaN
# Genre_disco                     NaN          NaN                NaN
# Genre_downtempo                 NaN          NaN                NaN
# Genre_folk                      NaN          NaN                NaN
# Genre_funk                      NaN          NaN                NaN
# Genre_gabba                     NaN          NaN                NaN
# Genre_hip hop/rap               NaN          NaN                NaN
# Genre_indie                     NaN          NaN                NaN
# Genre_jazz                      1.0          NaN                NaN
# Genre_latin                     NaN          1.0                NaN
# Genre_mellow gold               NaN          NaN                1.0
# Genre_metal                     NaN          NaN                NaN
# Genre_opera                     NaN          NaN                NaN
# Genre_pop                       NaN          NaN                NaN
# Genre_punk                      NaN          NaN                NaN
# Genre_reggae                    NaN          NaN                NaN
# Genre_rock                      NaN          NaN                NaN
# Genre_singer-songwriter         NaN          NaN                NaN
# Genre_soul                      NaN          NaN                NaN
#
#                          Genre_metal  Genre_opera  Genre_pop  Genre_punk  \
# BPM                              NaN          NaN        NaN         NaN
# Energy                           NaN          NaN        NaN         NaN
# Danceability                     NaN          NaN        NaN         NaN
# Loudness_db                      NaN          NaN        NaN         NaN
# Liveness                         NaN          NaN        NaN         NaN
# Valence                          NaN          NaN        NaN         NaN
# Duration                         NaN          NaN        NaN         NaN
# Acousticness                     NaN          NaN        NaN         NaN
# Speechiness                      NaN          NaN        NaN         NaN
# Popularity                       NaN          NaN        NaN         NaN
# Total Followers                  NaN          NaN        NaN         NaN
# yrs_since_release                NaN          NaN        NaN         NaN
# word_count_in_title              NaN          NaN        NaN         NaN
# Genre_adult standards            NaN          NaN        NaN         NaN
# Genre_alternative                NaN          NaN        NaN         NaN
# Genre_blues                      NaN          NaN        NaN         NaN
# Genre_cabaret                    NaN          NaN        NaN         NaN
# Genre_carnaval limburg           NaN          NaN        NaN         NaN
# Genre_celtic                     NaN          NaN        NaN         NaN
# Genre_chanson                    NaN          NaN        NaN         NaN
# Genre_classic                    NaN          NaN        NaN         NaN
# Genre_country/americana          NaN          NaN        NaN         NaN
# Genre_dance                      NaN          NaN        NaN         NaN
# Genre_disco                      NaN          NaN        NaN         NaN
# Genre_downtempo                  NaN          NaN        NaN         NaN
# Genre_folk                       NaN          NaN        NaN         NaN
# Genre_funk                       NaN          NaN        NaN         NaN
# Genre_gabba                      NaN          NaN        NaN         NaN
# Genre_hip hop/rap                NaN          NaN        NaN         NaN
# Genre_indie                      NaN          NaN        NaN         NaN
# Genre_jazz                       NaN          NaN        NaN         NaN
# Genre_latin                      NaN          NaN        NaN         NaN
# Genre_mellow gold                NaN          NaN        NaN         NaN
# Genre_metal                      1.0          NaN        NaN         NaN
# Genre_opera                      NaN          1.0        NaN         NaN
# Genre_pop                        NaN          NaN        1.0         NaN
# Genre_punk                       NaN          NaN        NaN         1.0
# Genre_reggae                     NaN          NaN        NaN         NaN
# Genre_rock                       NaN          NaN        NaN         NaN
# Genre_singer-songwriter          NaN          NaN        NaN         NaN
# Genre_soul                       NaN          NaN        NaN         NaN
#
#                          Genre_reggae  Genre_rock  Genre_singer-songwriter  \
# BPM                               NaN         NaN                      NaN
# Energy                            NaN         NaN                      NaN
# Danceability                      NaN         NaN                      NaN
# Loudness_db                       NaN         NaN                      NaN
# Liveness                          NaN         NaN                      NaN
# Valence                           NaN         NaN                      NaN
# Duration                          NaN         NaN                      NaN
# Acousticness                      NaN         NaN                      NaN
# Speechiness                       NaN         NaN                      NaN
# Popularity                        NaN         NaN                      NaN
# Total Followers                   NaN         NaN                      NaN
# yrs_since_release                 NaN         NaN                      NaN
# word_count_in_title               NaN         NaN                      NaN
# Genre_adult standards             NaN         NaN                      NaN
# Genre_alternative                 NaN         NaN                      NaN
# Genre_blues                       NaN         NaN                      NaN
# Genre_cabaret                     NaN         NaN                      NaN
# Genre_carnaval limburg            NaN         NaN                      NaN
# Genre_celtic                      NaN         NaN                      NaN
# Genre_chanson                     NaN         NaN                      NaN
# Genre_classic                     NaN         NaN                      NaN
# Genre_country/americana           NaN         NaN                      NaN
# Genre_dance                       NaN         NaN                      NaN
# Genre_disco                       NaN         NaN                      NaN
# Genre_downtempo                   NaN         NaN                      NaN
# Genre_folk                        NaN         NaN                      NaN
# Genre_funk                        NaN         NaN                      NaN
# Genre_gabba                       NaN         NaN                      NaN
# Genre_hip hop/rap                 NaN         NaN                      NaN
# Genre_indie                       NaN         NaN                      NaN
# Genre_jazz                        NaN         NaN                      NaN
# Genre_latin                       NaN         NaN                      NaN
# Genre_mellow gold                 NaN         NaN                      NaN
# Genre_metal                       NaN         NaN                      NaN
# Genre_opera                       NaN         NaN                      NaN
# Genre_pop                         NaN         NaN                      NaN
# Genre_punk                        NaN         NaN                      NaN
# Genre_reggae                      1.0         NaN                      NaN
# Genre_rock                        NaN         1.0                      NaN
# Genre_singer-songwriter           NaN         NaN                      1.0
# Genre_soul                        NaN         NaN                      NaN
#
#                          Genre_soul
# BPM                             NaN
# Energy                          NaN
# Danceability                    NaN
# Loudness_db                     NaN
# Liveness                        NaN
# Valence                         NaN
# Duration                        NaN
# Acousticness                    NaN
# Speechiness                     NaN
# Popularity                      NaN
# Total Followers                 NaN
# yrs_since_release               NaN
# word_count_in_title             NaN
# Genre_adult standards           NaN
# Genre_alternative               NaN
# Genre_blues                     NaN
# Genre_cabaret                   NaN
# Genre_carnaval limburg          NaN
# Genre_celtic                    NaN
# Genre_chanson                   NaN
# Genre_classic                   NaN
# Genre_country/americana         NaN
# Genre_dance                     NaN
# Genre_disco                     NaN
# Genre_downtempo                 NaN
# Genre_folk                      NaN
# Genre_funk                      NaN
# Genre_gabba                     NaN
# Genre_hip hop/rap               NaN
# Genre_indie                     NaN
# Genre_jazz                      NaN
# Genre_latin                     NaN
# Genre_mellow gold               NaN
# Genre_metal                     NaN
# Genre_opera                     NaN
# Genre_pop                       NaN
# Genre_punk                      NaN
# Genre_reggae                    NaN
# Genre_rock                      NaN
# Genre_singer-songwriter         NaN
# Genre_soul                      1.0

# %%
#total followers has highest correlation with popularity
corr['Popularity'].sort_values(ascending=False)
# Out:
# Popularity                 1.000000
# Total Followers            0.334425
# Loudness_db                0.166836
# yrs_since_release          0.157486
# Danceability               0.145635
# Speechiness                0.111980
# Genre_alternative          0.108686
# Energy                     0.104241
# Valence                    0.096250
# Genre_soul                 0.090088
# Genre_rock                 0.062635
# Genre_hip hop/rap          0.054523
# Genre_adult standards      0.045496
# Genre_folk                 0.042441
# Genre_reggae               0.037404
# Genre_latin                0.030150
# Genre_mellow gold          0.026568
# Genre_punk                 0.021250
# Genre_jazz                 0.021032
# word_count_in_title        0.016657
# Genre_disco                0.014305
# Genre_dance                0.013337
# Genre_opera                0.012105
# Genre_blues               -0.001723
# BPM                       -0.004635
# Genre_funk                -0.011585
# Genre_gabba               -0.013274
# Genre_pop                 -0.018253
# Genre_downtempo           -0.031272
# Genre_celtic              -0.038115
# Genre_metal               -0.038320
# Genre_singer-songwriter   -0.044823
# Genre_classic             -0.045324
# Genre_chanson             -0.050437
# Genre_country/americana   -0.066696
# Duration                  -0.066938
# Acousticness              -0.088924
# Liveness                  -0.111654
# Genre_carnaval limburg    -0.113802
# Genre_cabaret             -0.148005
# Genre_indie               -0.301386
# Name: Popularity, dtype: float64

# %%
#fig,ax=plt.subplots(figsize=(20,15))

#sns.heatmap(corr)

sns.set(style="white")
# Compute the correlation matrix
#corr = np.abs(data.corr())
# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))
# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)
# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=1, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# **Inference: ** By performing EDA on the Spotify dataset, the relationship between different audio features and a song's popularity is found. Usage of scatter plots, box plots, histograms, and other visualization techniques to identify trends and patterns in the data. Songs with higher danceability or energy tend to be more popular, or that certain genres or artists have higher average popularity scores.

# %% [markdown]
# #### Statistical Tests
# - Are genre's that are often lumpted together, significantly different?
#
# #### Two Sample T Test
#
# Ho: There is no statistical significance between avg popularity for alternative and rock songs
#
# Ha: The average popularity of both genres is different.
#
# Conclusion: reject Ho

# %%
#two sample T test
stats.ttest_ind(df[df['Top Genre']=='rock']['Popularity'],df[df['Top Genre']=='alternative']['Popularity'])
# Out:
# Ttest_indResult(statistic=-3.6624778368437463, pvalue=0.000262775550119648)

# %% [markdown]
# #### ANOVA test
#
# Ho: These genres are not statistically different in relation to popularity
#
# Ha: These genres are statistically different
#
# Conclusion: fail to reject Ho, perhaps all three genres do not to be included in the final model

# %%
#ANOVA 
#these genres are not statistically different in reference to popularity
pop_popularity=df[df['Top Genre']=='pop']['Popularity']
dance_popularity=df[df['Top Genre']=='dance']['Popularity']
disco_popularity=df[df['Top Genre']=='disco']['Popularity']
stat,pval = stats.f_oneway(pop_popularity,dance_popularity,disco_popularity)
stat,pval
# Out:
# (0.47549761031567406, 0.621881510819406)

# %% [markdown]
# ## Modeling

# %%
data=pd.read_pickle('Data/data.pkl')

# %%
#not scaled or transformed data
data.rename(columns={'Total Followers':'Artist_Followers','Genre_adult standards':'Genre_adult_standards','Genre_carnaval limburg':'Genre_carnaval_limburg','Genre_mellow gold':'Genre_mellow_gold','Genre_hip_hop/rap':'Genre_hip_hop_rap','Genre_country/americana':'Genre_country_americana','Genre_singer-songwriter':'Genre_singer_songwriter'},inplace=True)

# %%
data.columns
# Out:
# Index(['BPM', 'Energy', 'Danceability', 'Loudness_db', 'Liveness', 'Valence',
#        'Duration', 'Acousticness', 'Speechiness', 'Popularity',
#        'Artist_Followers', 'yrs_since_release', 'word_count_in_title',
#        'Genre_adult_standards', 'Genre_alternative', 'Genre_blues',
#        'Genre_cabaret', 'Genre_carnaval_limburg', 'Genre_celtic',
#        'Genre_chanson', 'Genre_classic', 'Genre_country_americana',
#        'Genre_dance', 'Genre_disco', 'Genre_downtempo', 'Genre_folk',
#        'Genre_funk', 'Genre_gabba', 'Genre_hip hop/rap', 'Genre_indie',
#        'Genre_jazz', 'Genre_latin', 'Genre_mellow_gold', 'Genre_metal',
#        'Genre_opera', 'Genre_pop', 'Genre_punk', 'Genre_reggae', 'Genre_rock',
#        'Genre_singer_songwriter', 'Genre_soul'],
#       dtype='object')

# %%
#Per EDA, relationship between song audio features and my target appeared to be non-linear
features_to_transform=['BPM','Energy','Danceability','Loudness_db','Liveness','Valence','Duration','Acousticness','Speechiness']

# %%
#creating polynomial interactions between song audio elements
polynomial_features= PolynomialFeatures(degree=2)
x_poly=polynomial_features.fit(data[features_to_transform])
x_poly_df=pd.DataFrame(x_poly.transform(data[features_to_transform]),columns=x_poly.get_feature_names(data[features_to_transform].columns))

# %%
#dropping duplicates to concat with other features and target variable
x_poly_df.drop(columns=['1','BPM', 'Energy', 'Danceability', 'Loudness_db', 'Liveness',
       'Valence', 'Duration', 'Acousticness', 'Speechiness'],inplace=True)

# %%
#datafame of Y, all original features, polynomial transformations of all song audio variables
data3=pd.concat([data,x_poly_df],axis=1)

# %%
data3.shape
# Out:
# (1995, 86)

# %%
data3.columns
# Out:
# Index(['BPM', 'Energy', 'Danceability', 'Loudness_db', 'Liveness', 'Valence',
#        'Duration', 'Acousticness', 'Speechiness', 'Popularity',
#        'Artist_Followers', 'yrs_since_release', 'word_count_in_title',
#        'Genre_adult_standards', 'Genre_alternative', 'Genre_blues',
#        'Genre_cabaret', 'Genre_carnaval_limburg', 'Genre_celtic',
#        'Genre_chanson', 'Genre_classic', 'Genre_country_americana',
#        'Genre_dance', 'Genre_disco', 'Genre_downtempo', 'Genre_folk',
#        'Genre_funk', 'Genre_gabba', 'Genre_hip hop/rap', 'Genre_indie',
#        'Genre_jazz', 'Genre_latin', 'Genre_mellow_gold', 'Genre_metal',
#        'Genre_opera', 'Genre_pop', 'Genre_punk', 'Genre_reggae', 'Genre_rock',
#        'Genre_singer_songwriter', 'Genre_soul', 'BPM^2', 'BPM Energy',
#        'BPM Danceability', 'BPM Loudness_db', 'BPM Liveness', 'BPM Valence',
#        'BPM Duration', 'BPM Acousticness', 'BPM Speechiness', 'Energy^2',
#        'Energy Danceability', 'Energy Loudness_db', 'Energy Liveness',
#        'Energy Valence', 'Energy Duration', 'Energy Acousticness',
#        'Energy Speechiness', 'Danceability^2', 'Danceability Loudness_db',
#        'Danceability Liveness', 'Danceability Valence',
#        'Danceability Duration', 'Danceability Acousticness',
#        'Danceability Speechiness', 'Loudness_db^2', 'Loudness_db Liveness',
#        'Loudness_db Valence', 'Loudness_db Duration',
#        'Loudness_db Acousticness', 'Loudness_db Speechiness', 'Liveness^2',
#        'Liveness Valence', 'Liveness Duration', 'Liveness Acousticness',
#        'Liveness Speechiness', 'Valence^2', 'Valence Duration',
#        'Valence Acousticness', 'Valence Speechiness', 'Duration^2',
#        'Duration Acousticness', 'Duration Speechiness', 'Acousticness^2',
#        'Acousticness Speechiness', 'Speechiness^2'],
#       dtype='object')

# %%
#setting target and features for models
target_final=data3['Popularity']
features_final=data3.drop(columns='Popularity')

# %%
#test train split of final complete dataset with transformed variables
x_train, x_test, y_train, y_test = train_test_split(features_final, target_final, random_state=32,test_size=0.2)

# %%
#scaler for all x train and x test variables 
scaler = StandardScaler()
scaler.fit(x_train)
x_train_scaled =pd.DataFrame(data=scaler.transform(x_train), columns=features_final.columns)
x_test_scaled =pd.DataFrame(data=scaler.transform(x_test), columns=features_final.columns)

# %% [markdown]
# #### Model 1
# - one feature 'artist_followers' to predict popularity
# - scaled feature
# - not transformed
# - setting a baseline
#
# Takeaways: This was the highest correlated original feature, the model did not perform well.

# %%
#baseline model, one feature - not transformed
one_feat=['Artist_Followers']
lm_one = LinearRegression()

lm_one = lm_one.fit(x_train_scaled[one_feat], y_train)

y_pred_lm_one=lm_one.predict(x_train_scaled[one_feat])

train_rmse_lm_one = np.sqrt(metrics.mean_squared_error(y_train, y_pred_lm_one))

y_pred_test_lm_one = lm_one.predict(x_test_scaled[one_feat])

test_rmse_lm_one = np.sqrt(metrics.mean_squared_error(y_test, y_pred_test_lm_one))


print("Train RMSE",(train_rmse_lm_one), "Test RMSE: ", (test_rmse_lm_one))
print ("R squared:", lm_one.score(x_test_scaled[one_feat], y_test))
# Out:
# Train RMSE 13.62929279821175 Test RMSE:  13.122795454623718
# Score: 0.09626134685727272

# %% [markdown]
# #### Model 2
# - all features (85) included in model
# - all transformed/interaction song elements
# - all original features (un-transformed)
#
# Takeaways: The model performed considerably better with the combination of original feautures and interactions.  However, 85 features is a bit too much for this dataset, so features need to be eliminated.

# %%
lm_two = LinearRegression()

lm_two = lm_two.fit(x_train_scaled, y_train)

y_pred_lm_two=lm_two.predict(x_train_scaled)

train_rmse_lm_two = np.sqrt(metrics.mean_squared_error(y_train, y_pred_lm_two))

y_pred_test_lm_two = lm_two.predict(x_test_scaled)

test_rmse_lm_two = np.sqrt(metrics.mean_squared_error(y_test, y_pred_test_lm_two))


print("Train RMSE", train_rmse_lm_two, "Test RMSE: ", test_rmse_lm_two)
print ("R squared:", lm_two.score(x_test_scaled, y_test))
# Out:
# Train RMSE 11.674108004991659 Test RMSE:  11.83547054321551
# R squared: 0.2648749934756638

# %% [markdown]
# #### Model 3
#
# - Recursive wrapper method of feature selection applied
# - 46 features selected
#
#
# Takeaways: Improved the model slightly from the last model, utilizing only 46 features instead of 85.

# %%
#model 3 with selected features as determined by RFECV 
#recursive wrapper method - feature selection

from sklearn.feature_selection import RFECV
ols = linear_model.LinearRegression()

# Create recursive feature eliminator that scores features by mean squared errors
selector = RFECV(estimator=ols, step=1, cv=5, scoring='neg_mean_squared_error')

# Fit recursive feature eliminator 
selector.fit(x_train_scaled, y_train)

#creating lists of selected/removed feature names
selected_columns = x_train_scaled.columns[selector.support_]
removed_columns = x_train_scaled.columns[~selector.support_]

lm_three = LinearRegression()

lm_three = lm_three.fit(x_train_scaled[selected_columns], y_train)

y_pred_lm_three=lm_three.predict(x_train_scaled[selected_columns])

train_rmse_lm_three = np.sqrt(metrics.mean_squared_error(y_train, y_pred_lm_three))

y_pred_test_lm_three = lm_three.predict(x_test_scaled[selected_columns])

test_rmse_lm_three = np.sqrt(metrics.mean_squared_error(y_test, y_pred_test_lm_three))


print("Train RMSE", train_rmse_lm_three, "Test RMSE: ", test_rmse_lm_three)
print ("R Squared:", lm_three.score(x_test_scaled[selected_columns], y_test))
# Out:
# Train RMSE 11.79488031456517 Test RMSE:  11.827278406499781
# R Squared: 0.2658923016310828

# %% [markdown]
# #### Model 4
# - Lasso feature selection applied on 46 recurvise wrapper selected features
#
# Takeaways: This model performed better, 43 features were selected

# %%
from sklearn.linear_model import Lasso

lasso = Lasso(alpha=0.1, normalize=False)

lasso.fit(x_train_scaled[selected_columns],y_train)

y_train_pred_lasso = lasso.predict(x_train_scaled[selected_columns])
y_pred_lasso = lasso.predict(x_test_scaled[selected_columns])

train_rmse_lasso = metrics.mean_absolute_error(y_train, y_train_pred_lasso)
test_rmse_lasso = np.sqrt(metrics.mean_squared_error(y_test, y_pred_lasso))
print('Training Error: '+ str(train_rmse_lasso) )
print('Testing Error: '+ str(test_rmse_lasso) )

print("R Squared:", lasso.score(x_test_scaled[selected_columns],y_test))
# Out:
# Training Error: 9.58024751131949
# Testing Error: 11.631622670900851
# R Squared: 0.28997972722295406

# %%
lasso_coef01 = pd.DataFrame(data=lasso.coef_).T
lasso_coef01.columns = x_train_scaled[selected_columns].columns
lasso_coef01 = lasso_coef01.T.sort_values(by=0).T
lasso_coef01.plot(kind='bar', title='Model Coefficients', legend=False, figsize=(16,8))
lasso_coef01.T
# Out:
#                                   0
# Genre_indie               -4.135311
# Danceability Duration     -3.512693
# Danceability^2            -1.936331
# Genre_pop                 -1.918394
# Acousticness Speechiness  -1.918193
# Genre_rock                -1.868481
# Energy Speechiness        -1.857362
# Duration Speechiness      -1.713904
# Genre_cabaret             -1.711373
# Danceability Speechiness  -1.650424
# Genre_carnaval_limburg    -1.606067
# Duration^2                -1.559638
# Loudness_db               -1.463257
# Energy Liveness           -1.406398
# Valence Speechiness       -1.396639
# Valence                   -1.310813
# Acousticness^2            -1.256812
# Genre_country_americana   -1.254895
# BPM Duration              -1.003518
# Loudness_db Valence       -0.960618
# Energy Acousticness       -0.840650
# Genre_funk                -0.824506
# Genre_singer_songwriter   -0.788071
# Danceability Acousticness -0.771321
# Energy^2                  -0.603048
# BPM Valence               -0.523040
# Duration Acousticness     -0.444439
# BPM                       -0.000000
# Energy Danceability       -0.000000
# Energy Valence             0.000000
# Valence^2                  0.475302
# BPM Energy                 0.562897
# Loudness_db^2              0.793606
# Valence Duration           1.421225
# BPM^2                      1.623118
# Acousticness               1.684140
# BPM Liveness               1.715205
# Loudness_db Liveness       1.996616
# Danceability Loudness_db   2.531429
# BPM Acousticness           2.589645
# yrs_since_release          3.390208
# BPM Loudness_db            3.785003
# Artist_Followers           3.825231
# Duration                   4.224249
# Speechiness                7.271339
# Danceability               8.372209

# %% [markdown]
# #### Model 5 - final model
#
# - Lasso feature selection used on all 85 features
# - Model ran with Lasso selected features
# - 34 features selected
#
# Takeaways:  This model performed the best in terms of predicting similarly on test/train data, and highest r-squared with the least amount of features.

# %%
from sklearn.feature_selection import SelectFromModel
from sklearn.linear_model import LassoCV
import warnings
warnings.filterwarnings('ignore')

sel=SelectFromModel(LassoCV())
sel.fit(x_train_scaled,y_train)


selected_feats=x_train_scaled.columns[(sel.get_support())]
print('total features: {}'.format((x_train.shape[1])))
print('selected features: {}'.format(len(selected_feats)))
print('features with coefficients shrank to zero: {}'.format(
      np.sum(sel.estimator_.coef_ == 0)))
# Out:
# total features: 85
# selected features: 32
# features with coefficients shrank to zero: 53

# %%
#Model 5 linear regression with lasso only selected features
lm_five = LinearRegression()

lm_five = lm_five.fit(x_train_scaled[selected_feats], y_train)

y_pred_lm_five=lm_five.predict(x_train_scaled[selected_feats])

train_rmse_lm_five = np.sqrt(metrics.mean_squared_error(y_train, y_pred_lm_five))

y_pred_test_lm_five = lm_five.predict(x_test_scaled[selected_feats])

test_rmse_lm_five = np.sqrt(metrics.mean_squared_error(y_test, y_pred_test_lm_five))


print("Train RMSE", train_rmse_lm_five, "Test RMSE: ", test_rmse_lm_five)
print ("R Squared:", lm_five.score(x_test_scaled[selected_feats], y_test))
# Out:
# Train RMSE 11.864271670187073 Test RMSE:  11.688024481674052
# R Squared: 0.28307724716525395

# %%
#coefficients of this model

coef_df=pd.DataFrame(lm_five.coef_)
dftest=pd.DataFrame(selected_feats)
coeff_df=pd.concat([dftest,coef_df],axis=1)
coeff_df.columns='Feature','Coef'

coeff_df.sort_values(by='Coef',ascending=False)
# Out:
#                      Feature      Coef
# 1           Artist_Followers  3.913116
# 2          yrs_since_release  3.438344
# 5          Genre_alternative  1.595203
# 0               Danceability  1.451896
# 29      Loudness_db Duration  1.077671
# 14                Genre_folk  0.975183
# 24           BPM Loudness_db  0.839291
# 26        Energy Loudness_db  0.819347
# 22                Genre_soul  0.698843
# 33             Speechiness^2  0.644560
# 25           BPM Speechiness  0.639510
# 28      Loudness_db Liveness  0.620527
# 4      Genre_adult_standards  0.609777
# 23          BPM Danceability  0.489335
# 17                Genre_jazz  0.410135
# 12               Genre_dance  0.407675
# 18         Genre_mellow_gold  0.174865
# 6                Genre_blues -0.198683
# 13           Genre_downtempo -0.220277
# 27             Loudness_db^2 -0.229876
# 31         Liveness Duration -0.252561
# 9               Genre_celtic -0.255651
# 3        word_count_in_title -0.344870
# 19               Genre_metal -0.351809
# 20                 Genre_pop -0.357962
# 10             Genre_classic -0.406849
# 21   Genre_singer_songwriter -0.523359
# 30                Liveness^2 -0.596763
# 15                Genre_funk -0.691020
# 32  Acousticness Speechiness -0.743931
# 11   Genre_country_americana -0.810561
# 7              Genre_cabaret -1.259741
# 8     Genre_carnaval_limburg -1.274282
# 16               Genre_indie -3.470467

# %% [markdown]
# #### Scatterplot of the final model's predictions vs true values
#
# Some predictions were slighly off but there is a general pattern to the plots.

# %%
plt.scatter(y_test, y_pred_test_lm_five)
plt.xlabel("True Values")
plt.ylabel("Predictions")
plt.title("True Values Vs Predictions")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ### Concluding Thoughts

# %% [markdown]
# **Inference: **: Artist followers, years since released, danceability, Duration plays important roles in the popularity of the song.
